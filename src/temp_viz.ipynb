# %%
import pandas as pd
import numpy as np

# %%
df_mov = pd.read_table('../data/movie.metadata.tsv', header=None)

# %%
sum(df_mov[4].isna())/len(df_mov)
# Out:
# 0.8972241592346558

# %%
df_mov.iloc[6,:]
# Out:
# 0                                             18998739
# 1                                           /m/04jcqvw
# 2                            The Sorcerer's Apprentice
# 3                                                 2002
# 4                                                  NaN
# 5                                                 86.0
# 6                   {"/m/02h40lc": "English Language"}
# 7                         {"/m/0hzlz": "South Africa"}
# 8    {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# Name: 6, dtype: object

# %%
df_mov.iloc[6,2]
# Out:
# "The Sorcerer's Apprentice"
